# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlosVerse/Data-Science/blob/main/%5BHTML%5DPanoramadoCOVID_19noBrasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img alt="Colaboratory logo" width="15%" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png">
#
# #### **Data Science na Prática 4.0**
# *by [sigmoidal.ai](https://sigmoidal.ai)*
#
# ---

# %% [markdown]
# # Panorama do COVID-19 no Brasil
#
# COVID-19 é uma doença infecciosa causada por recém-descoberto coronavírus.
#
# Transmitido principalmente por meio de gotículas provenientes de tosses ou espirros de pessoas infectadas, a gravidade dos sintomas varia muito de pessoa para pessoa.
#
# Fato é, não se sabe muita coisa a respeito do COVID-19. Estudos estão sendo realizados no mundo todo, porém os resultados ainda não são conclusivos e definitivos.
#
# <center><img alt="Colaboratory logo" width="50%" src="https://static.poder360.com.br/2022/12/coronavirus-imagem-1-848x477.jpg"></center>
#
# Até o presente momento, observa-se que cerca de 80% dos casos confirmados são assintomáticos e rápidos. A maioria das pessoas que se encaixam nesse grupo, se recupera sem nenhuma sequela.
#
# No entanto, 15% das pessoas terão infecções graves e precisarão de oxigênio. O restante das pessoas, que representam 5%, serão classificadas como infecções muito graves e precisarão de ventilação assistida, por meio de respiradores mecânicos em ambiente hospitalar.
#
# Com o objetivo de elevar a consciência situacional a respeito do COVID-19 no Brasil, irei realizar uma análise sobre os dados públicos da doença.

# %% [markdown]
# ## Obtenção dos Dados
#
# *Descreva a fonte dos seus dados e um breve resumo sobre o que se pode esperar desse dataset.*
#
# *Fale sobre a dificuldade de se analisar uma doença novas, os conflitos existentes entre os dados dos governos federal, estaduais e os não oficiais.*
#
# ### Dicionário de Variáveis
# * *Construa um dicionário de variáveis.*
#     * *A descrição do nome de cada coluna pode ser encontrada [neste link](https://github.com/owid/covid-19-data/blob/master/public/data/owid-covid-data-codebook.md).*
#
# ### Importando os dados do COVID-19
#
# * Você deve entrar no site [https://github.com/owid/covid-19-data/tree/master/public/data](https://github.com/owid/covid-19-data/tree/master/public/data) e conhecer a base dados. Usaremos o formato `csv` neste projeto.
#     * Caso encontre algum problema em baixar diretamente do repositório oficial, você pode usar [este meu link](https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/owid-covid-data.csv) (atualizado até 14 de junho de 2020).
# * *Importe os dados do `csv` para a variável `df`.*
#     * *`pd.read_csv("endereco_do_arquivo.csv")`*

# %% [markdown]
# <!DOCTYPE html>
# <html lang="pt">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title></title>
#   <style>
#           h1 {
#           font-size: 50px; /* Aumenta o tamanho da fonte do título exibido na página */
#           text-align: center; /* Centraliza o título */
#       }
#       table {
#           width: 100%;
#           border-collapse: collapse;
#       }
#
#       th, td {
#           padding: 12px;
#           text-align: left;
#           border: 1px solid #ddd;
#       }
#
#       th {
#           background-color: #f2f2f2;
#       }
#
#       /* Estilo de hover para linha */
#       tr:hover {
#           background-color: #007BFF; /* Cor azul para o hover */
#           color: white; /* Texto branco para contraste */
#           cursor: pointer; /* Muda o cursor para indicar interatividade */
#       }
#   </style>
# </head>
# <body>
#     <h1>📚 Dicionário de Variáveis COVID-19</h1>
#
# <table>
#   <thead>
#       <tr>
#           <th>COLUNA</th>
#           <th>FONTE</th>
#           <th>CATEGORIA</th>
#           <th>DESCRIÇÃO</th>
#       </tr>
#   </thead>
#   <tbody>
#       <tr>
#           <td><strong>iso_code</strong></td>
#           <td>International Organization for Standardization</td>
#           <td>Outros</td>
#           <td>Código do país de 3 letras (ISO 3166-1 alpha-3). Regiões definidas pela OWID (ex: continentes como Europa) têm o prefixo "OWID_", ex: "OWID_AFR".</td>
#       </tr>
#       <tr>
#           <td><strong>continent</strong></td>
#           <td>Our World in Data</td>
#           <td>Outros</td>
#           <td>Continente da localização geográfica.</td>
#       </tr>
#       <tr>
#           <td><strong>location</strong></td>
#           <td>Our World in Data</td>
#           <td>Outros</td>
#           <td>Localização geográfica.</td>
#       </tr>
#       <tr>
#           <td><strong>date</strong></td>
#           <td>Our World in Data</td>
#           <td>Outros</td>
#           <td>Data da observação.</td>
#       </tr>
#       <tr>
#           <td><strong>total_cases</strong></td>
#           <td>COVID-19 Dashboard by the WHO</td>
#           <td>Casos Confirmados</td>
#           <td>Total de casos confirmados de COVID-19. As contagens podem incluir casos prováveis, quando reportados.</td>
#       </tr>
#       <tr>
#           <td><strong>new_cases</strong></td>
#           <td>COVID-19 Dashboard by the WHO</td>
#           <td>Casos Confirmados</td>
#           <td>Novos casos confirmados de COVID-19. As contagens podem incluir casos prováveis, quando reportados. Em casos raros onde nossa fonte de dados reporta uma mudança diária negativa devido a uma correção de dados, definimos essa métrica como "NA".</td>
#       </tr>
#       <tr>
#           <td><strong>new_cases_smoothed</strong></td>
#           <td>COVID-19 Dashboard by the WHO</td>
#           <td>Casos Confirmados</td>
#           <td>Novos casos confirmados de COVID-19 (média suavizada dos dados ao longo de 7 dias). As contagens podem incluir casos prováveis, quando notificados.</td>
#       </tr>
#       <tr>
#           <td><strong>total_deaths</strong></td>
#           <td>COVID-19 Dashboard by the WHO</td>
#           <td>Mortes Confirmadas</td>
#           <td>Total de mortes atribuídas ao COVID-19. Pode incluir mortes prováveis, quando reportadas.</td>
#       </tr>
#       <tr>
#           <td><strong>new_deaths</strong></td>
#           <td>COVID-19 Dashboard by the WHO</td>
#           <td>Mortes Confirmadas</td>
#           <td>Novas mortes atribuídas à COVID-19. Pode incluir mortes prováveis, quando reportadas. Em casos raros, quando nossa fonte reporta uma mudança negativa diária devido a uma correção de dados, definimos essa métrica como NA.</td>
#       </tr>
#       <tr>
#           <td><strong>new_deaths_smoothed</strong></td>
#           <td>COVID-19 Dashboard by the WHO</td>
#           <td>Mortes Confirmadas</td>
#           <td>Novas mortes atribuídas à COVID-19 (média suavizada dos dados ao longo de 7 dias). Os números podem incluir mortes prováveis, quando reportadas.</td>
#       </tr>
#       <tr>
#           <td><strong>total_cases_per_million</strong></td>
#           <td>COVID-19 Dashboard by the WHO</td>
#           <td>Casos Confirmados</td>
#           <td>Total de casos confirmados de COVID-19 por 1.000.000 de pessoas. Pode incluir casos prováveis, quando reportados.</td>
#       </tr>
#       <tr>
#           <td><strong>new_cases_per_million</strong></td>
#           <td>COVID-19 Dashboard by the WHO</td>
#           <td>Casos Confirmados</td>
#           <td>Novos casos confirmados de COVID-19 por 1.000.000 de pessoas. Pode incluir casos prováveis, quando reportados.</td>
#       </tr>
#       <tr>
#           <td><strong>new_cases_smoothed_per_million</strong></td>
#           <td>COVID-19 Dashboard by the WHO</td>
#           <td>Casos Confirmados</td>
#           <td>Novos casos confirmados de COVID-19 (média suavizada dos dados ao longo de 7 dias) por 1.000.000 de pessoas. Pode incluir casos prováveis, quando reportados.</td>
#       </tr>
#       <tr>
#           <td><strong>total_deaths_per_million</strong></td>
#           <td>COVID-19 Dashboard by the WHO</td>
#           <td>Mortes Confirmadas</td>
#           <td>Total de mortes atribuídas ao COVID-19 por 1.000.000 de pessoas. Pode incluir mortes prováveis, quando reportadas.</td>
#       </tr>
#       <tr>
#           <td><strong>new_deaths_per_million</strong></td>
#           <td>COVID-19 Dashboard by the WHO</td>
#           <td>Mortes Confirmadas</td>
#           <td>Novas mortes atribuídas ao COVID-19 por 1.000.000 de pessoas. Pode incluir mortes prováveis, quando reportadas.</td>
#       </tr>
#       <tr>
#           <td><strong>new_deaths_smoothed_per_million</strong></td>
#           <td>COVID-19 Dashboard by the WHO</td>
#           <td>Mortes Confirmadas</td>
#           <td>Novas mortes atribuídas ao COVID-19 (média suavizada dos dados ao longo de 7 dias) por 1.000.000 de pessoas. Pode incluir mortes prováveis, quando reportadas.</td>
#       </tr>
#       <tr>
#           <td><strong>reproduction_rate</strong></td>
#           <td>Arroyo Marioli et al. (2020)</td>
#           <td>Taxa de Reprodução</td>
#           <td>Estimativa em tempo real da taxa de reprodução efetiva (R) do COVID-19.</td>
#       </tr>
#       <tr>
#           <td><strong>icu_patients</strong></td>
#           <td>National government reports and European CDC</td>
#           <td>Hospital & UTI</td>
#           <td>Número de pacientes com COVID-19 em unidades de terapia intensiva (UTIs) em um determinado dia.</td>
#       </tr>
#       <tr>
#           <td><strong>icu_patients_per_million</strong></td>
#           <td>National government reports and European CDC</td>
#           <td>Hospital & UTI</td>
#           <td>Número de pacientes com COVID-19 em unidades de terapia intensiva (UTIs) em um determinado dia por 1.000.000 de pessoas</td>
#       </tr>
#       <tr>
#           <td><strong>hosp_patients</strong></td>
#           <td>National government reports and European CDC</td>
#           <td>Hospital & UTI</td>
#           <td>Número de pacientes com COVID-19 hospitalizados em um determinado dia.</td>
#       </tr>
#       <tr>
#           <td><strong>hosp_patients_per_million</strong></td>
#           <td>National government reports and European CDC</td>
#           <td>Hospital & UTI</td>
#           <td>Número de pacientes com COVID-19 hospitalizados em um determinado dia por 1.000.000 de pessoas.</td>
#       </tr>
#       <tr>
#           <td><strong>weekly_icu_admissions</strong></td>
#           <td>National government reports and European CDC</td>
#           <td>Hospital & UTI</td>
#           <td>Número de pacientes com COVID-19 recém-admitidos em unidades de terapia intensiva (UTIs) em uma semana (data do relatório e os 6 dias anteriores)</td>
#       </tr>
#       <tr>
#           <td><strong>weekly_icu_admissions_per_million</strong></td>
#           <td>National government reports and European CDC</td>
#           <td>Hospital & UTI</td>
#           <td>Número de pacientes com COVID-19 recém-admitidos em unidades de terapia intensiva (UTIs) em uma semana por 1.000.000 de pessoas (data do relatório e os 6 dias anteriores).</td>
#       </tr>
#       <tr>
#           <td><strong>weekly_hosp_admissions</strong></td>
#           <td>National government reports and European CDC</td>
#           <td>Hospital & UTI</td>
#           <td>Número de pacientes com COVID-19 recém-admitidos em hospitais em uma semana (data do relatório e os 6 dias anteriores).</td>
#       </tr>
#       <tr>
#           <td><strong>weekly_hosp_admissions_per_million</strong></td>
#           <td>National government reports and European CDC</td>
#           <td>Hospital & UTI</td>
#           <td>Número de pacientes com COVID-19 recém-admitidos em hospitais em uma semana por 1.000.000 de pessoas (data do relatório e os 6 dias anteriores)</td>
#       </tr>
#       <tr>
#           <td><strong>total_tests</strong></td>
#           <td>National government reports</td>
#           <td>Testes & Positividade</td>
#           <td>Total de testes realizados para COVID-19.</td>
#       </tr>
#       <tr>
#           <td><strong>new_tests</strong></td>
#           <td>National government reports</td>
#           <td>Testes & Positividade</td>
#           <td>Novos testes para COVID-19 (calculados apenas para dias consecutivos).</td>
#       </tr>
#       <tr>
#           <td><strong>total_tests_per_thousand</strong></td>
#           <td>National government reports</td>
#           <td>Testes & Positividade</td>
#           <td>Total de testes para COVID-19 por 1.000 pessoas.</td>
#       </tr>
#       <tr>
#           <td><strong>new_tests_per_thousand</strong></td>
#           <td>National government reports</td>
#           <td>Testes & Positividade</td>
#           <td>Novos testes para COVID-19 por 1.000 pessoas.</td>
#       </tr>
#       <tr>
#           <td><strong>new_tests_smoothed</strong></td>
#           <td>National government reports</td>
#           <td>Testes & Positividade</td>
#           <td>Novos testes para COVID-19 (média suavizada dos dados ao longo de 7 dias). Para os países que não reportam dados de testes diariamente, assumimos que a testagem mudou igualmente a cada dia durante os períodos em que não foram reportados dados. Isso gera uma série completa de dados diários, que é então média em uma janela deslizante de 7 dias.</td>
#       </tr>
#       <tr>
#           <td><strong>new_tests_smoothed_per_thousand</strong></td>
#           <td>National government reports</td>
#           <td>Testes & Positividade</td>
#           <td>Novos testes para COVID-19 (média suavizada dos dados ao longo de 7 dias) por 1.000 pessoas.</td>
#       </tr>
#       <tr>
#           <td><strong>positive_rate</strong></td>
#           <td>National government reports</td>
#           <td>Testes & Positividade</td>
#           <td>Porcentagem de testes de COVID-19 positivos, apresentada como uma média de 7 dias (inverso de tests_per_case).</td>
#       </tr>
#       <tr>
#           <td><strong>tests_per_case</strong></td>
#           <td>National government reports</td>
#           <td>Testes & Positividade</td>
#           <td>Testes realizados por novo caso confirmado de COVID-19, apresentado como uma média de 7 dias (inverso de positive_rate).</td>
#       </tr>
#       <tr>
#           <td><strong>tests_units</strong></td>
#           <td>National government reports</td>
#           <td>Testes & Positividade</td>
#           <td>Unidades utilizadas para relatar dados de testagem de COVID-19. Um arquivo de país não pode conter unidades mistas. As unidades válidas são 'pessoas testadas' (número de pessoas testadas), 'testes realizados' (número de testes realizados. Uma única pessoa pode ser testada mais de uma vez em um dado dia) e 'amostras testadas' (número de amostras testadas. Em alguns casos, mais de uma amostra pode ser necessária para realizar um determinado teste).</td>
#       </tr>
#       <tr>
#           <td><strong>total_vaccinations</strong></td>
#           <td>National government reports</td>
#           <td>Vacinação</td>
#           <td>Número total de doses de vacina contra a COVID-19 administradas</td>
#       </tr>
#       <tr>
#           <td><strong>people_vaccinated</strong></td>
#           <td>National government reports</td>
#           <td>Vacinação</td>
#           <td>Número total de pessoas que receberam pelo menos uma dose da vacina contra COVID-19.</td>
#       </tr>
#       <tr>
#           <td><strong>people_fully_vaccinated</strong></td>
#           <td>National government reports</td>
#           <td>Vacinação</td>
#           <td>Número total de pessoas que receberam todas as doses prescritas pelo protocolo inicial de vacinação.</td>
#       </tr>
#       <tr>
#           <td><strong>total_boosters</strong></td>
#           <td>National government reports</td>
#           <td>Vacinação</td>
#           <td>Número total de doses de reforço contra a COVID-19 administradas (doses administradas além do número prescrito pelo protocolo de vacinação)</td>
#       </tr>
#       <tr>
#           <td><strong>new_vaccinations</strong></td>
#           <td>National government reports</td>
#           <td>Vacinação</td>
#           <td>Novas doses de vacina contra a COVID-19 administradas (somente calculadas para dias consecutivos)</td>
#       </tr>
#       <tr>
#           <td><strong>new_vaccinations_smoothed</strong></td>
#           <td>National government reports</td>
#           <td>Vacinação</td>
#           <td>Novas doses de vacina contra a COVID-19 administradas (média móvel de 7 dias). Para países que não reportam dados de vacinação diariamente, assumimos que a vacinação variou igualmente a cada dia durante os períodos em que não há dados reportados. Isso gera uma série completa de dados diários, que é então média sobre uma janela móvel de 7 dias.</td>
#       </tr>
#       <tr>
#           <td><strong>total_vaccinations_per_hundred</strong></td>
#           <td>National government reports</td>
#           <td>Vacinação</td>
#           <td>Número total de doses de vacina administradas por 100 pessoas na população total.</td>
#       </tr>
#       <tr>
#           <td><strong>people_vaccinated_per_hundred</strong></td>
#           <td>National government reports</td>
#           <td>Vacinação</td>
#           <td>Número total de pessoas que receberam pelo menos uma dose por 100 pessoas na população total.</td>
#       </tr>
#       <tr>
#           <td><strong>people_fully_vaccinated_per_hundred</strong></td>
#           <td>National government reports</td>
#           <td>Vacinação</td>
#           <td>Número total de pessoas que receberam todas as doses prescritas por 100 pessoas na população total.</td>
#       </tr>
#       <tr>
#           <td><strong>total_boosters_per_hundred</strong></td>
#           <td>National government reports</td>
#           <td>Vacinação</td>
#           <td>Número total de doses de reforço administradas por 100 pessoas na população total.</td>
#       </tr>
#       <tr>
#           <td><strong>new_vaccinations_smoothed_per_million</strong></td>
#           <td>National government reports</td>
#           <td>Vacinação</td>
#           <td>Novas doses de vacina administradas (média suavizada dos dados ao longo de 7 dias) por 1.000.000 de pessoas.</td>
#       </tr>
#       <tr>
#           <td><strong>new_people_vaccinated_smoothed</strong></td>
#           <td>National government reports</td>
#           <td>Vacinação</td>
#           <td>Número diário de pessoas recebendo a primeira dose da vacina (média suavizada de 7 dias).</td>
#       </tr>
#       <tr>
#           <td><strong>new_people_vaccinated_smoothed_per_hundred</strong></td>
#           <td>National government reports</td>
#           <td>Vacinação</td>
#           <td>Número diário de pessoas recebendo a primeira dose da vacina (média suavizada dos dados ao longo de 7 dias) por 100 pessoas na população total</td>
#       </tr>
#       <tr>
#           <td><strong>stringency_index</strong></td>
#           <td>Oxford COVID-19 Government Response Tracker, Blavatnik School of Government</td>
#           <td>Respostas políticas</td>
#           <td>Índice de Rigor da Resposta do Governo: medida composta com base em 9 indicadores de resposta, incluindo o fechamento de escolas, fechamento de locais de trabalho e proibição de viagens, reescalonada para um valor de 0 a 100 (100 = resposta mais rigorosa)</td>
#       </tr>
#       <tr>
#           <td><strong>population</strong></td>
#           <td>United Nations, Department of Economic and Social Affairs, Population Division, World Population Prospects 2019 Revision</td>
#           <td>Outros</td>
#           <td>População (valores mais recentes disponíveis). Veja https://github.com/owid/covid-19-data/blob/master/scripts/input/un/population_latest.csv a lista completa de fontes.</td>
#       </tr>
#       <tr>
#           <td><strong>population_density</strong></td>
#           <td>World Bank World Development Indicators, sourced from Food and Agriculture Organization and World Bank estimates</td>
#           <td>Outros</td>
#           <td>Densidade populacional, número de pessoas dividido pela área de terra, medida em quilômetros quadrados (km²), no ano mais recente disponível.</td>
#       </tr>
#       <tr>
#           <td><strong>median_age</strong></td>
#           <td>UN Population Division, World Population Prospects, 2017 Revision</td>
#           <td>Outros</td>
#           <td>Idade mediana da população, projeção da ONU para 2020.</td>
#       </tr>
#       <tr>
#           <td><strong>aged_65_older</strong></td>
#           <td>World Bank World Development Indicators based on age/sex distributions of United Nations World Population Prospects 2017 Revision</td>
#           <td>Outros</td>
#           <td>Porcentagem da população com 65 anos ou mais, ano mais recente disponível.</td>
#       </tr>
#       <tr>
#           <td><strong>aged_70_older</strong></td>
#           <td>United Nations, Department of Economic and Social Affairs, Population Division (2017), World Population Prospects 2017 Revision</td>
#           <td>Outros</td>
#           <td>Porcentagem da população com 70 anos ou mais em 2015.</td>
#       </tr>
#       <tr>
#           <td><strong>gdp_per_capita</strong></td>
#           <td>World Bank World Development Indicators, source from World Bank, International Comparison Program database</td>
#           <td>Outros</td>
#           <td>Produto Interno Bruto (PIB) a paridade do poder de compra (PPC) (dólares internacionais constantes de 2011), ano mais recente disponível.</td>
#       </tr>
#       <tr>
#           <td><strong>extreme_poverty</strong></td>
#           <td>World Bank World Development Indicators, sourced from World Bank Development Research Group</td>
#           <td>Outros</td>
#           <td>Porcentagem da população vivendo em extrema pobreza, ano mais recente disponível desde 2010.</td>
#       </tr>
#       <tr>
#           <td><strong>cardiovasc_death_rate</strong></td>
#           <td>	Global Burden of Disease Collaborative Network, Global Burden of Disease Study 2017 Results</td>
#           <td>Outros</td>
#           <td>Taxa de morte por doenças cardiovasculares (número anual de mortes por 100.000 pessoas) em 2017.</td>
#       </tr>
#       <tr>
#           <td><strong>diabetes_prevalence</strong></td>
#           <td>World Bank World Development Indicators, sourced from International Diabetes Federation, Diabetes Atlas</td>
#           <td>Outros</td>
#           <td>Prevalência de diabetes (% da população entre 20 a 79 anos) em 2017.</td>
#       </tr>
#   <tr>
#       <td><strong>female_smokers</strong></td>
#       <td>World Bank World Development Indicators, sourced from World Health Organization, Global Health Observatory Data Repository</td>
#       <td>Outros</td>
#       <td>Porcentagem de mulheres que fumam, ano mais recente disponível.</td>
#   </tr>
#   <tr>
#       <td><strong>male_smokers</strong></td>
#       <td>World Bank World Development Indicators, sourced from World Health Organization, Global Health Observatory Data Repository</td>
#       <td>Outros</td>
#       <td>Porcentagem de homens que fumam, ano mais recente disponível.</td>
#   </tr>
#   <tr>
#       <td><strong>handwashing_facilities</strong></td>
#       <td>United Nations Statistics Division</td>
#       <td>Outros</td>
#       <td>Porcentagem da população com instalações básicas para lavagem das mãos no local, ano mais recente disponível</td>
#   </tr>
#   <tr>
#       <td><strong>hospital_beds_per_thousand</strong></td>
#       <td>	OECD, Eurostat, World Bank, national government records and other sources</td>
#       <td>Outros</td>
#       <td>Leitos de hospital por 1.000 pessoas, ano mais recente disponível desde 2010</td>
#   </tr>
#   <tr>
#       <td><strong>life_expectancy</strong></td>
#       <td>James C. Riley, Clio Infra, United Nations Population Division</td>
#       <td>Outros</td>
#       <td>Expectativa de vida ao nascer em 2019.</td>
#   </tr>
#   <tr>
#       <td><strong>human_development_index</strong></td>
#       <td>United Nations Development Programme (UNDP)</td>
#       <td>Outros</td>
#       <td>Um índice composto que mede o desempenho médio em três dimensões básicas do desenvolvimento humano—uma vida longa e saudável, conhecimento e um padrão de vida digno. Valores para 2019, importados de http://hdr.undp.org/en/indicators/137506</td>
#   </tr>
#   <tr>
#       <td><strong>excess_mortality</strong></td>
#       <td>Human Mortality Database (2021), World Mortality Dataset (2021)</td>
#       <td>Mortalidade Excedente</td>
#       <td>Diferença percentual entre o número de mortes semanais ou mensais registradas em 2020–2021 e o número projetado de mortes para o mesmo período com base nos anos anteriores. Para mais informações, veja https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality</td>
#   </tr>
#   <tr>
#       <td><strong>excess_mortality_cumulative</strong></td>
#       <td>Human Mortality Database (2021), World Mortality Dataset (2021)</td>
#       <td>Mortalidade Excedente</td>
#       <td>Diferença percentual entre o número cumulativo de mortes desde 1º de janeiro de 2020 e o número de mortes cumulativas projetadas para o mesmo período com base nos anos anteriores. Para mais informações, veja https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality</td>
#   </tr>
#   <tr>
#       <td><strong>excess_mortality_cumulative_absolute</strong></td>
#       <td>Human Mortality Database (2021), World Mortality Dataset (2021)</td>
#       <td>Mortalidade Excedente</td>
#       <td>Diferença cumulativa entre o número de mortes registradas desde 1º de janeiro de 2020 e o número de mortes projetadas para o mesmo período com base nos anos anteriores. Para mais informações, veja https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality</td>
#   </tr>
#   <tr>
#       <td><strong>excess_mortality_cumulative_per_million</strong></td>
#       <td>Human Mortality Database (2021), World Mortality Dataset (2021)</td>
#       <td>Mortalidade Excedente</td>
#       <td>Diferença cumulativa entre o número de mortes registradas desde 1º de janeiro de 2020 e o número de mortes projetadas para o mesmo período com base nos anos anteriores, por milhão de pessoas. Para mais informações, veja https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality</td>
#   </tr>
#       </tbody>
#   </table>
#
#   </body>
#   </html>

# %%
# importar as bibliotecas necessárias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# importar o dataset COVID-19 para um DataaFrame
df = pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/refs/heads/master/public/data/owid-covid-data.csv")

# %% [markdown]
# ## Análise Exploratória dos Dados
#
# *Crie uma breve contextualização sobre o que será feito na fase de Análise Exploratória de Dados...*
#
# ...
#
# ...
#
# ### Análise Exploratória Inicial
#
# * *Visualizar as 5 primeiras entradas*
#     * `df.head()`
# * *Qual o tamanho do seu DataFrame*
#     * `df.shape`
# * *Extrair e imprimir os nomes das colunas*
#     * `df.columns`
# * *Quais os tipos das variáveis*
#     * `df.dtypes`
# * *Identifique a porcentagem de valores ausentes das colunas*
#     * `df.isnull().sum() / df.shape[0]` ou
#     * `(df.isnull().sum() / df.shape[0]).sort_values(ascending=False)` *para ordem decrescente.*
# * *Transforme a coluna `date` no formato `datetime`*
#     * `df.date = pd.to_datetime(df.date)`
# * *Ver para a data mais atual, quais os países que têm mais casos e mortes. Veja o exemplo:*
#     * `df.loc[df.date == '2020-06-14'].sort_values(by="total_cases", ascending=False)`
#     * `df.loc[df.date == '2020-06-14'].sort_values(by="total_deaths", ascending=False)`
# * Plotar um gráfico de barras para os 5 países com mais mortes
#     * `df.loc[df.date == '2020-06-14', ['location', 'total_deaths']].sort_values(by="total_deaths", ascending=False)[1:6]`
#     * `ax.bar('location', 'total_deaths', data=top5_total_deaths)`
# * Plotar um gráfico de linhas para ver a evolução do total de casos de COVID-19 no mundo.
#     * `df.loc[df.location == "World", "total_deaths"].reset_index(drop=True).plot()`
# * [OPCIONAL] Plotar um gráfico de dispersão considerando `gdp_per_capita` (ou seja, o PIB dos países) pelo número total de mortos. Pegue a data mais recente apenas.
#     * Lembre-se que não é nada conclusivo, pois envolve fatores como proporcão de testes, etc.

# %% [markdown]
# Vamos......

# %%
df.head()

#df.loc[df.iso_code == 'UK']#.sort_values(by="total_cases", ascending=False)

#df.loc[df['date'].str.startswith('2022')]

# %%
df.shape
#df['reproduction_rate'].unique()
#df.total_cases_per_million

# %%
df.dtypes

# %%
#df.isnull().sum() / df.shape[0]

#df.isnull().sum() / df.shape[0] * 100
(df.isnull().sum() / df.shape[0] * 100).sort_values(ascending=False)

# %%
#df['date'].dtypes

print(df['date'].dtypes)

# %%
#transformando date em datetime
df.date = pd.to_datetime(df.date)
print(df['date'].dtypes)

# %%
#Paises/Regiões com mais casos de mortes
#df.loc[df.date == '2020-06-14'].sort_values(by="total_cases", ascending=False)
df.loc[df.date == '2020-06-14'].sort_values(by="total_deaths", ascending=False)

# %%
#df.loc[df.date == '2020-06-14', ['location', 'total_deaths']].sort_values(by="total_deaths", ascending=False)[1:6]
#ax.bar('location', 'total_deaths', data=top5_total_deaths)
df.loc[df.location == "World", "total_deaths"].reset_index(drop=True).plot()

# %%
#Valores ausentes
#(df.isnull().sum() / df.shape[0] * 100).sort_values(ascending=False)
(df.isnull().mean()*100).sort_values(ascending=False)

# %%
df.hist(bins=15, figsize=(20,10));

# %% [markdown]
# ### Análise Exploratória para o Brasil
#
# * Criar uma cópia do DataFrame apenas com o Brasil
#     * `df_brasil = df.loc[df.location == "Brazil"].copy()`
# * Identificar quando foi registrada a primeira morte no Brasil
# * Identificar quantos dias demorou para registrarmos a primeira morte, considerando o primeiro caso de COVID-19 registrado.
# * Plotar gráficos de linha em escalas linear e logarítmica para os casos totais e mortes totais.

# %%
# !pip install nbconvert

# %%
# !jupyter nbconvert --ClearOutputPreprocessor.enabled=True --to notebook --output /content/notebook_limpo.ipynb "/content/PanoramadoCOVID-19noBrasil.ipynb"
# !jupyter nbconvert --to html "/content/drive/My Drive/Panorama do COVID-19 no Brasil.ipynb"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive.flush_and_unmount()

# %% [markdown]
# <!DOCTYPE html>
# <html lang="pt">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Tabela Interativa</title>
#     <style>
#         table {
#             width: 100%;
#             border-collapse: collapse;
#         }
#
#         th, td {
#             padding: 12px;
#             text-align: left;
#             border: 1px solid #ddd;
#         }
#
#         th {
#             background-color: #f2f2f2;
#         }
#
#         tr:hover {
#             background-color: #f1f1f1; /* Cor de destaque ao passar o mouse */
#             cursor: pointer;
#         }
#     </style>
# </head>
# <body>
#
# <h2>📚 Dicionário de Variáveis</h2>
#
# <p>Este dicionário de dados descreve as fontes utilizadas para coletar informações sobre as variáveis **continente** e **localização**, além de duas novas variáveis. Abaixo, estão as fontes de dados associadas a cada variável:</p>
#
# <table>
#     <thead>
#         <tr>
#             <th>COLUNA</th>
#             <th>FONTE</th>
#             <th>CATEGORIA</th>
#             <th>DESCRIÇÃO</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td><strong>iso_code</strong></td>
#             <td>International Organization for Standardization</td>
#             <td>Outros</td>
#             <td>ISO 3166-1 alpha-3 – três letras para os códigos dos países.</td>
#         </tr>
#         <tr>
#             <td><strong>continent</strong></td>
#             <td>Our World in Data</td>
#             <td>Outros</td>
#             <td>Continente de localização geográfica.</td>
#         </tr>
#         <tr>
#             <td><strong>location</strong></td>
#             <td>Our World in Data</td>
#             <td>Outros</td>
#             <td>Localização geográfica.</td>
#         </tr>
#         <tr>
#             <td><strong>date</strong></td>
#             <td>Our World in Data</td>
#             <td>Outros</td>
#             <td>Data da observação.</td>
#         </tr>
#         <tr>
#             <td><strong>total_cases</strong></td>
#             <td>COVID-19 Dashboard by the WHO</td>
#             <td>Casos confirmados</td>
#             <td>Total de casos confirmados de COVID-19.</td>
#         </tr>
#         <!-- Adicione mais linhas conforme necessário -->
#     </tbody>
# </table>
#
# </body>
# </html>

# %% [markdown]
# ## Conclusão
#
# *Escreva suas conclusões e análises sobre os dados relativos à COVID-19...*
